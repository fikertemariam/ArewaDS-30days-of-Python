# %% [markdown]
# # Exercises: Day 19

# %%
#Exercises: Level 1

# %%
#1.Write a function which count number of lines and number of words in a text. All the files are in the data the folder:

# %%
#a) Read obama_speech.txt file and count number of lines and words
def count_lines_and_words(file_path):
    try:
        with open(file_path, 'r', encoding='utf-8') as file:
            # Read the content of the file
            content = file.read()

            # Count the number of lines
            lines = content.split('\n')
            num_lines = len(lines)

            # Count the number of words
            words = content.split()
            num_words = len(words)

            # Print the results
            print(f"Number of lines: {num_lines}")
            print(f"Number of words: {num_words}")

    except FileNotFoundError:
        print(f"Error: File '{file_path}' not found.")

# Specify the file path
file_path = r'C:\Users\Dell\Desktop\ArewaDS Workshop\Arewads_30days\DAY 19\obama_speech.txt'

# Call the function with the specified file path
count_lines_and_words(file_path)
# Out:
# Number of lines: 67
# Number of words: 2400

# %%
#b) Read michelle_obama_speech.txt file and count number of lines and words
def count_lines_and_words(file_path):
    try:
        with open(file_path, 'r', encoding='utf-8') as file:
            # Read the content of the file
            content = file.read()

            # Count the number of lines
            lines = content.split('\n')
            num_lines = len(lines)

            # Count the number of words
            words = content.split()
            num_words = len(words)

            # Print the results
            print(f"Number of lines: {num_lines}")
            print(f"Number of words: {num_words}")

    except FileNotFoundError:
        print(f"Error: File '{file_path}' not found.")

# Specify the file path for michelle_obama_speech.txt
michelle_file_path = r'C:\Users\Dell\Desktop\ArewaDS Workshop\Arewads_30days\DAY 19\michelle_obama_speech.txt'

# Call the function with the specified file path
count_lines_and_words(michelle_file_path)
# Out:
# Number of lines: 83
# Number of words: 2204

# %%
#c) Read donald_speech.txt file and count number of lines and words
def count_lines_and_words(file_path):
    try:
        with open(file_path, 'r', encoding='utf-8') as file:
            # Read the content of the file
            content = file.read()

            # Count the number of lines
            lines = content.split('\n')
            num_lines = len(lines)

            # Count the number of words
            words = content.split()
            num_words = len(words)

            # Print the results
            print(f"Number of lines: {num_lines}")
            print(f"Number of words: {num_words}")

    except FileNotFoundError:
        print(f"Error: File '{file_path}' not found.")

# Specify the file path for donald_speech.txt
donald_file_path = r'C:\Users\Dell\Desktop\ArewaDS Workshop\Arewads_30days\DAY 19\donald_speech.txt'

# Call the function with the specified file path
count_lines_and_words(donald_file_path)
# Out:
# Number of lines: 49
# Number of words: 1259

# %%
#d) Read melina_trump_speech.txt file and count number of lines and words
def count_lines_and_words(file_path):
    try:
        with open(file_path, 'r', encoding='utf-8') as file:
            # Read the content of the file
            content = file.read()

            # Count the number of lines
            lines = content.split('\n')
            num_lines = len(lines)

            # Count the number of words
            words = content.split()
            num_words = len(words)

            # Print the results
            print(f"Number of lines: {num_lines}")
            print(f"Number of words: {num_words}")

    except FileNotFoundError:
        print(f"Error: File '{file_path}' not found.")

# Specify the file path for melina_trump_speech.txt
melina_file_path = r'C:\Users\Dell\Desktop\ArewaDS Workshop\Arewads_30days\DAY 19\melina_trump_speech.txt'

# Call the function with the specified file path
count_lines_and_words(melina_file_path)
# Out:
# Number of lines: 33
# Number of words: 1375

# %%
#Read the countries_data.json data file in data directory, create a function that finds the ten most spoken languages
import json

def most_spoken_languages(filename, top_n):
    try:
        with open(filename, 'r', encoding='utf-8') as file:
            data = json.load(file)

        languages_count = {}
        for country in data:
            if 'languages' in country:
                for language in country['languages']:
                    languages_count[language] = languages_count.get(language, 0) + 1

        sorted_languages = sorted(languages_count.items(), key=lambda x: x[1], reverse=True)

        return sorted_languages[:top_n]

    except FileNotFoundError:
        print(f"Error: File '{filename}' not found.")

# Specify the file path for countries_data.json
json_file_path = r'C:\Users\Dell\Desktop\ArewaDS Workshop\Arewads_30days\DAY 19\countries_data.json'

# Example usage with top 10 languages
result_10 = most_spoken_languages(filename=json_file_path, top_n=10)
print(result_10)

# Example usage with top 3 languages
result_3 = most_spoken_languages(filename=json_file_path, top_n=3)
print(result_3)
# Out:
# [('English', 91), ('French', 45), ('Arabic', 25), ('Spanish', 24), ('Portuguese', 9), ('Russian', 9), ('Dutch', 8), ('German', 7), ('Chinese', 5), ('Serbian', 4)]
# [('English', 91), ('French', 45), ('Arabic', 25)]

# %%
#3.Read the countries_data.json data file in data directory, create a function that creates a list of the ten most populated countries
import json

def most_populated_countries(filename, top_n):
    try:
        with open(filename, 'r', encoding='utf-8') as file:
            data = json.load(file)

        sorted_countries = sorted(data, key=lambda x: x['population'], reverse=True)

        return sorted_countries[:top_n]

    except FileNotFoundError:
        print(f"Error: File '{filename}' not found.")

# Specify the file path for countries_data.json
json_file_path = r'C:\Users\Dell\Desktop\ArewaDS Workshop\Arewads_30days\DAY 19\countries_data.json'

# Example usage with top 10 populated countries
result_10 = most_populated_countries(filename=json_file_path, top_n=10)
print(result_10)

# Example usage with top 3 populated countries
result_3 = most_populated_countries(filename=json_file_path, top_n=3)
print(result_3)
# Out:
# [{'name': 'China', 'capital': 'Beijing', 'languages': ['Chinese'], 'population': 1377422166, 'flag': 'https://restcountries.eu/data/chn.svg', 'currency': 'Chinese yuan'}, {'name': 'India', 'capital': 'New Delhi', 'languages': ['Hindi', 'English'], 'population': 1295210000, 'flag': 'https://restcountries.eu/data/ind.svg', 'currency': 'Indian rupee'}, {'name': 'United States of America', 'capital': 'Washington, D.C.', 'languages': ['English'], 'population': 323947000, 'flag': 'https://restcountries.eu/data/usa.svg', 'currency': 'United States dollar'}, {'name': 'Indonesia', 'capital': 'Jakarta', 'languages': ['Indonesian'], 'population': 258705000, 'flag': 'https://restcountries.eu/data/idn.svg', 'currency': 'Indonesian rupiah'}, {'name': 'Brazil', 'capital': 'Brasília', 'languages': ['Portuguese'], 'population': 206135893, 'flag': 'https://restcountries.eu/data/bra.svg', 'currency': 'Brazilian real'}, {'name': 'Pakistan', 'capital': 'Islamabad', 'languages': ['English', 'Urdu'], 'popu
# ...

# %%
#Exercises: Level 2

# %%
#4.Extract all incoming email addresses as a list from the email_exchange_big.txt file.
import re

def extract_email_addresses(file_path):
    try:
        with open(file_path, 'r', encoding='utf-8') as file:
            content = file.read()

            # Use a regular expression to find email addresses
            email_pattern = re.compile(r'\b[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Z|a-z]{2,}\b')
            email_addresses = re.findall(email_pattern, content)

            return email_addresses

    except FileNotFoundError:
        print(f"Error: File '{file_path}' not found.")

# Specify the file path for email_exchange_big.txt
txt_file_path = r'C:\Users\Dell\Desktop\ArewaDS Workshop\Arewads_30days\DAY 19\email_exchange_big.txt'

# Extract email addresses and print the result
email_addresses = extract_email_addresses(txt_file_path)
print(email_addresses)
# Out:
# ['stephen.marquard@uct.ac.za', 'postmaster@collab.sakaiproject.org', '200801051412.m05ECIaH010327@nakamura.uits.iupui.edu', 'source@collab.sakaiproject.org', 'source@collab.sakaiproject.org', 'source@collab.sakaiproject.org', 'source@collab.sakaiproject.org', 'stephen.marquard@uct.ac.za', 'source@collab.sakaiproject.org', 'stephen.marquard@uct.ac.za', 'stephen.marquard@uct.ac.za', 'louis@media.berkeley.edu', 'postmaster@collab.sakaiproject.org', '200801042308.m04N8v6O008125@nakamura.uits.iupui.edu', 'source@collab.sakaiproject.org', 'source@collab.sakaiproject.org', 'source@collab.sakaiproject.org', 'source@collab.sakaiproject.org', 'louis@media.berkeley.edu', 'source@collab.sakaiproject.org', 'louis@media.berkeley.edu', 'louis@media.berkeley.edu', 'zqian@umich.edu', 'postmaster@collab.sakaiproject.org', '200801042109.m04L92hb007923@nakamura.uits.iupui.edu', 'source@collab.sakaiproject.org', 'source@collab.sakaiproject.org', 'source@collab.sakaiproject.org', 'source@collab.sakaiproje
# ...

# %%
#5.Find the most common words in the English language. Call the name of your function find_most_common_words, it will take two parameters - a string or a file and a positive integer, indicating the number of words. Your function will return an array of tuples in descending order. Check the output
"""    # Your output should look like this
    print(find_most_common_words('sample.txt', 10))
    [(10, 'the'),
    (8, 'be'),
    (6, 'to'),
    (6, 'of'),
    (5, 'and'),
    (4, 'a'),
    (4, 'in'),
    (3, 'that'),
    (2, 'have'),
    (2, 'I')]

    # Your output should look like this
    print(find_most_common_words('sample.txt', 5))

    [(10, 'the'),
    (8, 'be'),
    (6, 'to'),
    (6, 'of'),
    (5, 'and')]"""

# %%
import re
from collections import Counter

def find_most_common_words(input_data, num_words):
    # If input_data is a file path, read the content from the file
    if isinstance(input_data, str) and input_data.endswith('.txt'):
        try:
            with open(input_data, 'r', encoding='utf-8') as file:
                content = file.read()
        except FileNotFoundError:
            print(f"Error: File '{input_data}' not found.")
            return []
    elif isinstance(input_data, str):
        content = input_data
    else:
        print("Error: Invalid input data.")
        return []

    # Use regex to extract words from the content
    words = re.findall(r'\b\w+\b', content.lower())

    # Count the occurrences of each word
    word_counts = Counter(words)

    # Get the most common words
    most_common_words = [(count, word) for word, count in word_counts.items()]

    # Sort the list in descending order by count
    most_common_words.sort(reverse=True)

    return most_common_words[:num_words]

# Specify the file path for 'sample.txt'
file_path = r'C:\Users\Dell\Desktop\ArewaDS Workshop\Arewads_30days\DAY 19\sample.txt'

# Example usage with the top 10 most common words
result_10 = find_most_common_words(file_path, 10)
print(result_10)

# Example usage with the top 5 most common words
result_5 = find_most_common_words(file_path, 5)
print(result_5)
# Out:
# [(3, 'to'), (3, 'the'), (3, 'of'), (3, 'be'), (3, 'and'), (2, 'have'), (1, 'that'), (1, 'in'), (1, 'i'), (1, 'a')]
# [(3, 'to'), (3, 'the'), (3, 'of'), (3, 'be'), (3, 'and')]

# %%
#6.Use the function, find_most_frequent_words to find:

# %%
#a) The ten most frequent words used in Obama's speech
import re
from collections import Counter

def find_most_frequent_words(file_path, num_words):
    try:
        with open(file_path, 'r', encoding='utf-8') as file:
            content = file.read()
    except FileNotFoundError:
        print(f"Error: File '{file_path}' not found.")
        return []

    # Use regex to extract words from the content
    words = re.findall(r'\b\w+\b', content.lower())

    # Count the occurrences of each word
    word_counts = Counter(words)

    # Get the most frequent words
    most_frequent_words = [(count, word) for word, count in word_counts.items()]

    # Sort the list in descending order by count
    most_frequent_words.sort(reverse=True)

    return most_frequent_words[:num_words]

# Specify the file path for Obama's speech
obama_speech_path = r'C:\Users\Dell\Desktop\ArewaDS Workshop\Arewads_30days\DAY 19\obama_speech.txt'

# Example usage to find the ten most frequent words
result_obama = find_most_frequent_words(obama_speech_path, 10)
print(result_obama)
# Out:
# [(129, 'the'), (113, 'and'), (81, 'of'), (70, 'to'), (67, 'our'), (62, 'we'), (50, 'that'), (48, 'a'), (36, 'is'), (25, 'in')]

# %%
#b) The ten most frequent words used in Michelle's speech 
import re
from collections import Counter

def find_most_frequent_words(file_path, num_words):
    try:
        with open(file_path, 'r', encoding='utf-8') as file:
            content = file.read()
    except FileNotFoundError:
        print(f"Error: File '{file_path}' not found.")
        return []

    # Use regex to extract words from the content
    words = re.findall(r'\b\w+\b', content.lower())

    # Count the occurrences of each word
    word_counts = Counter(words)

    # Get the most frequent words
    most_frequent_words = [(count, word) for word, count in word_counts.items()]

    # Sort the list in descending order by count
    most_frequent_words.sort(reverse=True)

    return most_frequent_words[:num_words]

# Specify the file path for Michelle Obama's speech
michelle_speech_path = r'C:\Users\Dell\Desktop\ArewaDS Workshop\Arewads_30days\DAY 19\michelle_obama_speech.txt'

# Example usage to find the ten most frequent words
result_michelle = find_most_frequent_words(michelle_speech_path, 10)
print(result_michelle)
# Out:
# [(96, 'and'), (85, 'the'), (84, 'to'), (50, 'that'), (46, 'of'), (41, 'a'), (37, 'he'), (36, 'in'), (28, 's'), (28, 'my')]

# %%
#c) The ten most frequent words used in Trump's speech 
import re
from collections import Counter

def find_most_frequent_words(file_path, num_words):
    try:
        with open(file_path, 'r', encoding='utf-8') as file:
            content = file.read()
    except FileNotFoundError:
        print(f"Error: File '{file_path}' not found.")
        return []

    # Use regex to extract words from the content
    words = re.findall(r'\b\w+\b', content.lower())

    # Count the occurrences of each word
    word_counts = Counter(words)

    # Get the most frequent words
    most_frequent_words = [(count, word) for word, count in word_counts.items()]

    # Sort the list in descending order by count
    most_frequent_words.sort(reverse=True)

    return most_frequent_words[:num_words]

# Specify the file path for Donald Trump's speech
trump_speech_path = r'C:\Users\Dell\Desktop\ArewaDS Workshop\Arewads_30days\DAY 19\donald_speech.txt'

# Example usage to find the ten most frequent words
result_trump = find_most_frequent_words(trump_speech_path, 10)
print(result_trump)
# Out:
# [(65, 'the'), (59, 'and'), (44, 'we'), (40, 'will'), (38, 'of'), (32, 'to'), (30, 'our'), (20, 'is'), (17, 'america'), (13, 'for')]

# %%
#d) The ten most frequent words used in Melina's speech
import re
from collections import Counter

def find_most_frequent_words(file_path, num_words):
    try:
        with open(file_path, 'r', encoding='utf-8') as file:
            content = file.read()
    except FileNotFoundError:
        print(f"Error: File '{file_path}' not found.")
        return []

    # Use regex to extract words from the content
    words = re.findall(r'\b\w+\b', content.lower())

    # Count the occurrences of each word
    word_counts = Counter(words)

    # Get the most frequent words
    most_frequent_words = [(count, word) for word, count in word_counts.items()]

    # Sort the list in descending order by count
    most_frequent_words.sort(reverse=True)

    return most_frequent_words[:num_words]

# Specify the file path for Melania Trump's speech
melania_speech_path = r'C:\Users\Dell\Desktop\ArewaDS Workshop\Arewads_30days\DAY 19\melina_trump_speech.txt'

# Example usage to find the ten most frequent words
result_melania = find_most_frequent_words(melania_speech_path, 10)
print(result_melania)
# Out:
# [(77, 'and'), (55, 'to'), (52, 'the'), (29, 'is'), (28, 'i'), (27, 'for'), (25, 'of'), (24, 'that'), (22, 'a'), (21, 'you')]

# %%
#7.Write a python application that checks similarity between two texts. It takes a file or a string as a parameter and it will evaluate the similarity of the two texts. For instance check the similarity between the transcripts of Michelle's and Melina's speech. You may need a couple of functions, function to clean the text(clean_text), function to remove support words(remove_support_words) and finally to check the similarity(check_text_similarity). List of stop words are in the data directory

# %%
# !pip install scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import re
from collections import Counter
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

def clean_text(text):
    # Remove special characters, numbers, and convert to lowercase
    cleaned_text = re.sub(r'[^a-zA-Z\s]', '', text)
    return cleaned_text.lower()

def remove_support_words(text, stop_words):
    # Tokenize the text and remove stop words
    words = re.findall(r'\b\w+\b', text)
    filtered_words = [word for word in words if word not in stop_words]
    return ' '.join(filtered_words)

def check_text_similarity(text1, text2, stop_words):
    # Clean and remove support words from the texts
    cleaned_text1 = remove_support_words(clean_text(text1), stop_words)
    cleaned_text2 = remove_support_words(clean_text(text2), stop_words)

    # Use TF-IDF vectorizer to convert text to vectors
    vectorizer = TfidfVectorizer()
    vectors = vectorizer.fit_transform([cleaned_text1, cleaned_text2])

    # Calculate cosine similarity between the vectors
    similarity = cosine_similarity(vectors[0], vectors[1])[0][0]

    return similarity

def read_file(file_path):
    try:
        with open(file_path, 'r', encoding='utf-8') as file:
            content = file.read()
        return content
    except FileNotFoundError:
        print(f"Error: File '{file_path}' not found.")
        return None

# Specify the file paths
michelle_speech_path = r'C:\Users\Dell\Desktop\ArewaDS Workshop\Arewads_30days\DAY 19\michelle_obama_speech.txt'
melania_speech_path = r'C:\Users\Dell\Desktop\ArewaDS Workshop\Arewads_30days\DAY 19\melina_trump_speech.txt'
stop_words_path = r'C:\Users\Dell\Desktop\ArewaDS Workshop\Arewads_30days\DAY 19\stop_words.py'

# Read the text content and stop words
michelle_text = read_file(michelle_speech_path)
melania_text = read_file(melania_speech_path)
stop_words = read_file(stop_words_path).splitlines()

# Check the similarity between Michelle's and Melania's speeches
similarity_score = check_text_similarity(michelle_text, melania_text, stop_words)
print(f"Similarity Score: {similarity_score}")
# Out:
# Similarity Score: 0.8662891765482669

# %%
#8.Find the 10 most repeated words in the romeo_and_juliet.txt
import re
from collections import Counter

def find_most_repeated_words(file_path, num_words):
    try:
        with open(file_path, 'r', encoding='utf-8') as file:
            content = file.read()
    except FileNotFoundError:
        print(f"Error: File '{file_path}' not found.")
        return None

    # Use regex to extract words from the content
    words = re.findall(r'\b\w+\b', content.lower())

    # Count the occurrences of each word
    word_counts = Counter(words)

    # Get the most repeated words
    most_repeated_words = word_counts.most_common(num_words)

    return most_repeated_words

# Specify the file path for romeo_and_juliet.txt
file_path = r'C:\Users\Dell\Desktop\ArewaDS Workshop\Arewads_30days\DAY 19\romeo_and_juliet.txt'

# Find the 10 most repeated words
most_repeated_words = find_most_repeated_words(file_path, 10)

# Print the result
print(most_repeated_words)
# Out:
# [('the', 868), ('and', 800), ('to', 661), ('i', 658), ('of', 535), ('a', 530), ('is', 381), ('in', 378), ('that', 371), ('you', 367)]

# %%
#9.Read the hacker news csv file and find out: a) Count the number of lines containing python or Python b) Count the number lines containing JavaScript, javascript or Javascript c) Count the number lines containing Java and not JavaScript
import csv

def count_lines_with_keyword(file_path, keyword):
    try:
        with open(file_path, 'r', encoding='utf-8', newline='') as file:
            reader = csv.reader(file)
            lines_count = sum(1 for row in reader if keyword.lower() in row[1].lower())
        return lines_count
    except FileNotFoundError:
        print(f"Error: File '{file_path}' not found.")
        return None

# Specify the file path for hacker_news.csv
file_path = r'C:\Users\Dell\Desktop\ArewaDS Workshop\Arewads_30days\DAY 19\hacker_news.csv'

# Count the number of lines containing Python or python
python_lines_count = count_lines_with_keyword(file_path, 'python')
print(f"a) Number of lines containing Python or python: {python_lines_count}")

# Count the number of lines containing JavaScript, javascript, or Javascript
javascript_lines_count = count_lines_with_keyword(file_path, 'javascript')
print(f"b) Number of lines containing JavaScript, javascript, or Javascript: {javascript_lines_count}")

# Count the number of lines containing Java and not JavaScript
java_lines_count = count_lines_with_keyword(file_path, 'java')
javascript_lines_count = count_lines_with_keyword(file_path, 'javascript')
java_not_javascript_lines_count = java_lines_count - javascript_lines_count
print(f"c) Number of lines containing Java and not JavaScript: {java_not_javascript_lines_count}")
# Out:
# a) Number of lines containing Python or python: 160
# b) Number of lines containing JavaScript, javascript, or Javascript: 170
# c) Number of lines containing Java and not JavaScript: 57
